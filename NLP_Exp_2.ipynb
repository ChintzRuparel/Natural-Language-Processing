# %% [markdown]
# <a href="https://colab.research.google.com/github/ChintzRuparel/Natural-Language-Processing/blob/main/NLP_Exp2_C086.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aim: Introduction to Natural Language Processing using Text Analysis

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup

#Make a request to the website      
page = requests.get("https://jamesclear.com/best-books/best-selling")
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <!--[if IE 9]><html class="lt-ie10" lang="lang="en-US"" > <![endif]-->
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://use.typekit.net/tqf2ebt.css" rel="stylesheet"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO Premium plugin v19.5 (Yoast SEO v19.13) - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Best-Selling Books of All-Time: Top Selling Books by Ranking
#    </title>
#    <meta content="Looking for good books to read? This reading list shares the best-selling books of all-time and breaks down the top selling books by ranking." name="description">
#     <link href="https://jamesclear.com/best-books/best-selling" rel="canonical">
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
display = soup.find_all("strong")
#Find all the elements on the page with a specific html tag

for d in display:
  print(d.text)
# Out:
# #1 – Don Quixote
# #2 – A Tale of Two Cities
# #3 – The Lord of the Rings
# #4 – The Little Prince
# #5 – Harry Potter and the Sorcerer’s Stone
# #6 – And Then There Were None
# #7 – The Dream of the Red Chamber
# #8 – The Hobbit
# #9 – She: A History of Adventure
# #10 – The Lion, the Witch and the Wardrobe
# #11 – The Da Vinci Code
# #12 – Think and Grow Rich
# #13 – Harry Potter and the Half-Blood Prince
# #14 – The Catcher in the Rye
# #15 – The Alchemist
# #16 – Harry Potter and the Chamber of Secrets
# #17 – Harry Potter and the Prisoner of Azkaban
# #18 – Harry Potter and the Goblet of Fire
# #19 – Harry Potter and the Order of the Phoenix
# #20 – Harry Potter and the Deathly Hallows
# #21 – One Hundred Years of Solitude
# #22 – Lolita
# #23 – Anne of Green Gables
# #24 – Charlotte’s Web
# #25 – Black Beauty
# #1 – Harry Potter series
# #2 – Goosebumps series
# #3 – Perry Mason series
# #4 – Berenstain Bears series
# #5 – Choose Your Own Adventure series
# ...

# %%
# Find all the elements on the page that have a specific class
soup.find_all(class_="footnote")
# Out:
# [<li class="footnote" id="footnote-1-7342"><p>Sales data for the best-selling books can be found on <a href="https://en.wikipedia.org/wiki/List_of_best-selling_books" title="best-selling books of all-time">this page</a>.</p></li>,
#  <li class="footnote" id="footnote-2-7342"><p>Don Quixote was published in 1605, so it is very old and sales figures are hard to track. Although the exact number of copies sold is unknown, it is thought to be over 500 million and certainly more than any other non-political or non-religious book on the list.</p></li>]

# %% [markdown]
# #OCR

# %%
# !pip install opencv-python
# !pip install pytesseract
# !pip install tesseract
# !sudo apt install tesseract-ocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 21 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# ...

# %%
import pytesseract
import shutil
import os
import cv2
import random

try:
  from PIL import Image
except ImportError:
  import Image

# %%
img2 = Image.open('/content/eng_bw.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1486x668>

# %%
extractedInformation1 = pytesseract.image_to_string(Image.open('/content/eng_bw.png'))
extractedInformation1
# Out:
# 'Mild Splendour of the various-vested Night!\nMother of wildly-working visions! hail!\nI watch thy gliding, while with watery light\nThy weak eye glimmers through a fleecy veil;\nAnd when thou lovest thy pale orb to shroud\nBehind the gather’d blackness lost on high;\nAnd when thou dartest from the wind-rent cloud\nThy placid lightning o’er the awaken’d sky.\n\x0c'

# %% [markdown]
# #Observations and Learning
# I was able to learn and do web scrapping for text data using beautiful soup for amazon best-selling books and extracted text from images

# %% [markdown]
# #Conclusion
# I was successfully able to perform Natural Language Processing using Text Analysis

# %% [markdown]
# #Question of Curiosity
#
# **1.  How does one parse the HTML into a BeautifulSoup object given a response object?**</br>
# **Ans:**</br>
# BeautifulSoup() function helps us to parse the html file or you say the encoding in html.</br>
# htmlParse = BeautifulSoup(page.content, 'html.parser')
# </br></br>
# **2.  Given that soup.find_all(class_='items') returns a list, in order to get the first item, all you need to do is index. ( True/False)**</br>
# **Ans:**</br>
# True
# </br></br>
# **3.  Given the below html, how would this tag type be described in web scraping code?**</br>
# **Ans:**</br>
# 'h1', class_='sports'
# </br></br>
# **4.  List 3 Disadvantages of using Tesseract**</br>
# **Ans:**</br>
#
#
# *   Poor quality scans may produce poor quality OCR.
# *   It does not expose information about what font family text belongs to.
# *   The OCR is not as accurate as some commercial solutions available to us.
